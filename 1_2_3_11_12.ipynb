# %% [markdown]
# Question 1
# Perform the following operations using Python on a data set : read data from different formats(like csv, xls),indexing and selecting data, sort data, describe attributes of data, checking data types of each column. (Use Titanic Dataset).

# %%
import pandas as pd

# Reading data from different formats (like csv, xlsx)
titanic_df = pd.read_csv('Titanic.csv')
titanic_excel_df = pd.read_excel('Titanic.xlsx')
titanic_df.head()
# titanic_excel_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# Selecting Data

# %%
# Selecting the first column
single_col = titanic_df['PassengerId']
single_col
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
# Selecting multiple columns
multiple_col = titanic_df[['PassengerId', 'Survived', 'Name', 'Sex']]
multiple_col
# Out:
#      PassengerId  Survived                                          Name  \
# 0            892         0                              Kelly, Mr. James
# 1            893         1              Wilkes, Mrs. James (Ellen Needs)
# 2            894         0                     Myles, Mr. Thomas Francis
# 3            895         0                              Wirz, Mr. Albert
# 4            896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...       ...                                           ...
# 413         1305         0                            Spector, Mr. Woolf
# 414         1306         1                  Oliva y Ocana, Dona. Fermina
# 415         1307         0                  Saether, Mr. Simon Sivertsen
# 416         1308         0                           Ware, Mr. Frederick
# 417         1309         0                      Peter, Master. Michael J
#
#         Sex
# 0      male
# 1    female
# 2      male
# 3      male
# 4    female
# ...

# %%
# Selecting single row
single_row = titanic_df.iloc[3]
single_row
# Out:
# PassengerId                 895
# Survived                      0
# Pclass                        3
# Name           Wirz, Mr. Albert
# Sex                        male
# Age                        27.0
# SibSp                         0
# Parch                         0
# Ticket                   315154
# Fare                     8.6625
# Cabin                       NaN
# Embarked                      S
# Name: 3, dtype: object

# %%
# Selecting multiple rows
multiple_row = titanic_df.iloc[[3, 4, 17, 22]]
multiple_row
# Out:
#     PassengerId  Survived  Pclass  \
# 3           895         0       3
# 4           896         1       3
# 17          909         0       3
# 22          914         1       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3                               Wirz, Mr. Albert    male  27.0      0      0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 17                             Assaf, Mr. Gerios    male  21.0      0      0
# 22          Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0      0
#
#       Ticket     Fare Cabin Embarked
# 3     315154   8.6625   NaN        S
# 4    3101298  12.2875   NaN        S
# 17      2692   7.2250   NaN        C
# 22  PC 17598  31.6833   NaN        S

# %%
# Selecting some rows and some columns
some_rows_some_cols = titanic_df.iloc[[3, 4, 5], [1, 2, 4]]
some_rows_some_cols
# Out:
#    Survived  Pclass     Sex
# 3         0       3    male
# 4         1       3  female
# 5         0       3    male

# %% [markdown]
# Indexing Data

# %%
#Printing top 10 values
titanic_excel_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0       0.0     3.0
# 1        893.0       1.0     3.0
# 2        894.0       0.0     2.0
# 3        895.0       0.0     3.0
# 4        896.0       1.0     3.0
# 5        897.0       0.0     3.0
# 6        898.0       1.0     3.0
# 7        899.0       0.0     2.0
# 8        900.0       1.0     3.0
# 9        901.0       0.0     3.0
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5    0.0    0.0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0    1.0    0.0
# 2                     Myles, Mr. Thomas Francis    male  62.0    0.0    0.0
# 3                              Wirz, Mr. Albert    male  27.0    0.0    0.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0    1.0    1.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0    0.0    0.0
# ...

# %%
#Printing last 20 values
titanic_excel_df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 398       1290.0       0.0     3.0
# 399       1291.0       0.0     3.0
# 400       1292.0       1.0     1.0
# 401       1293.0       0.0     2.0
# 402       1294.0       1.0     1.0
# 403       1295.0       0.0     1.0
# 404       1296.0       0.0     1.0
# 405       1297.0       0.0     2.0
# 406       1298.0       0.0     2.0
# 407       1299.0       0.0     1.0
# 408       1300.0       1.0     3.0
# 409       1301.0       1.0     3.0
# 410       1302.0       1.0     3.0
# 411       1303.0       1.0     1.0
# 412       1304.0       1.0     3.0
# 413       1305.0       0.0     3.0
# 414       1306.0       1.0     1.0
# 415       1307.0       0.0     3.0
# 416       1308.0       0.0     3.0
# 417       1309.0       0.0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 398                   Larsson-Rondberg, Mr. Edvard A    male  22.0    0.0
# ...

# %%
# Access data of a certain position (pass position and label as parameters)
titanic_df.at[3, 'Name']
# Out:
# 'Wirz, Mr. Albert'

# %%
# Access data of a certain (row, col) position
titanic_df.iat[3, 5]
# Out:
# 27.0

# %%
# Checking for null values
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# Sort values

# %%
sorted_titanic_df = titanic_df.sort_values('Fare', ascending=False)
sorted_titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Question 2
# Perform the following operations using Python on the Telecom_Churn dataset. Compute and display summary statistics for each feature available in the dataset using separate commands for each statistic. (e.g. minimum value, maximum value, mean, range, standard deviation, variance and percentiles).

# %%
telephone_churn_df = pd.read_csv('telephone_churn.csv')
telephone_churn_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# Displaying summary statistic for each feature using seperate command

# %%
telephone_churn_df['State'].min()
# telephone_churn_df['State'].max()
# telephone_churn_df['State'].mean()
# telephone_churn_df['State'].median()
# telephone_churn_df['State'].mode()
# telephone_churn_df['State'].std()
# telephone_churn_df['State'].var()
# telephone_churn_df['State'].quantile(0.1) # 10th percentile
# telephone_churn_df['State'].quantile(0.5) # 50th percentile same as median
# telephone_churn_df['State'].quantile(0.99) # 99th percentile
# Out:
# 'AK'

# %%
# telephone_churn_df['Area code'].min()
telephone_churn_df['Area code'].max()
# telephone_churn_df['Area code'].mean()
# telephone_churn_df['Area code'].median()
# telephone_churn_df['Area code'].mode()
# telephone_churn_df['Area code'].std()
# telephone_churn_df['Area code'].var()
# telephone_churn_df['Area code'].quantile(0.1) # 10th percentile
# telephone_churn_df['Area code'].quantile(0.5) # 50th percentile same as median
# telephone_churn_df['Area code'].quantile(0.99) # 99th percentile
# Out:
# 510

# %%
# telephone_churn_df['Account length'].min()
# telephone_churn_df['Account length'].max()
telephone_churn_df['Account length'].mean()
# telephone_churn_df['Account length'].median()
# telephone_churn_df['Account length'].mode()
# telephone_churn_df['Account length'].std()
# telephone_churn_df['Account length'].var()
# telephone_churn_df['Account length'].quantile(0.1) # 10th percentile
# telephone_churn_df['Account length'].quantile(0.5) # 50th percentile same as median
# telephone_churn_df['Account length'].quantile(0.99) # 99th percentile
# Out:
# 100.62040510127532

# %%
# telephone_churn_df['Number vmail messages'].min()
# telephone_churn_df['Number vmail messages'].max()
# telephone_churn_df['Number vmail messages'].mean()
# telephone_churn_df['Number vmail messages'].median()
# telephone_churn_df['Number vmail messages'].mode()
# telephone_churn_df['Number vmail messages'].std()
# telephone_churn_df['Number vmail messages'].var()
# telephone_churn_df['Number vmail messages'].quantile(0.1) # 10th percentile
# telephone_churn_df['Number vmail messages'].quantile(0.5) # 50th percentile same as median
telephone_churn_df['Number vmail messages'].quantile(0.99)  # 99th percentile
# Out:
# 43.0

# %% [markdown]
# Question 3
# Perform the following operations using Python on the data set House_Price Prediction dataset. Compute standard deviation, variance and
# percentiles using separate commands, for each feature. Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
house_price_df = pd.read_csv('House-Price-Prediction-clean.csv')
house_price_df.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706        150          856  ...           0           61
# 1         978        284         1262  ...         298            0
# 2         486        434          920  ...           0           42
# 3         216        540          756  ...           0           35
# 4         655        490         1145  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %% [markdown]
# For printing stats using separate commands for each feature refer Question 2
#
# A histogram is basically used to represent data in the form of some groups. It is a type of bar plot where the X-axis represents the bin ranges while the Y-axis gives information about frequency. The hist() function is used to compute and create a histogram. In histogram, if we pass categorical data then it will automatically compute the frequency of that data i.e. how often each value occurred.

# %%
import matplotlib.pyplot as plt

# %%
# Histogram of Year Built
plt.hist(house_price_df['YearBuilt'])

# Adding Title to the Plot
plt.title("Histogram for Year Built")

# Setting the X and Y labels
plt.xlabel('Year Built')
plt.ylabel('Frequency')

plt.show()

# %%
# Histogram of Sale Price
plt.hist(house_price_df['SalePrice'])

# Adding Title to the Plot
plt.title("Histogram for Sale Price")

# Setting the X and Y labels
plt.xlabel('Sale Prices')
plt.ylabel('Frequency')

plt.show()

# %%
# Histogram of Living Area
plt.hist(house_price_df['GrLivArea'])

# Adding Title to the Plot
plt.title("Histogram for Living Area")

# Setting the X and Y labels
plt.xlabel('Living Area')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# Similarly try building histograms for different features

# %% [markdown]
# Question 11
# 11. Use Iris flower dataset and perform following :
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
from sklearn import datasets

iris_dataset = datasets.load_iris()
iris_df = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
iris_df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object

# %%
# Histogram of Living Area
plt.hist(iris_df['sepal length (cm)'])

# Adding Title to the Plot
plt.title("Histogram for Living Area")

# Setting the X and Y labels
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# For Histogram creation refer Question 3

# %% [markdown]
# 12.Use Iris flower dataset and perform following :
# 1. Create a box plot for each feature in the dataset.
# 2. Identify and discuss distributions and identify outliers from them.

# %% [markdown]
# Box Plot is the visual representation of the depicting groups of numerical data through their quartiles. Boxplot is also used for detect the outlier in data set. It captures the summary of the data efficiently with a simple box and whiskers and allows us to compare easily across groups. Boxplot summarizes a sample data using 25th, 50th and 75th percentiles. These percentiles are also known as the lower quartile, median and upper quartile.
#
# A box plot consist of 5 things.
#
# Minimum
# First Quartile or 25%
# Median (Second Quartile) or 50%
# Third Quartile or 75%
# Maximum

# %%
import seaborn as sns

# %%
# Draw a vertical boxplot grouped
# sns.set_style("whitegrid")

sns.boxplot(x = 'sepal width (cm)', y = 'sepal length (cm)', data = iris_df)
# Out:
# <AxesSubplot:xlabel='sepal width (cm)', ylabel='sepal length (cm)'>

# %%
# Draw a vertical boxplot grouped
# sns.set_style("whitegrid")

sns.boxplot(x = 'petal width (cm)', y = 'petal length (cm)', data = iris_df)
# Out:
# <AxesSubplot:xlabel='petal width (cm)', ylabel='petal length (cm)'>
